# %%
# !apt install fluidsynth
# !cp /usr/share/sounds/sf2/FluidR3_GM.sf2 ./font.sf2
# !pip install midi2audio
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fluidsynth is already the newest version (1.1.9-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...

# %%
from midi2audio import FluidSynth # https://coder-question-ko.com/cq-ko-blog/35745 참조
fs = FluidSynth(sound_font='font.sf2')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from midi2audio import FluidSynth

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Music Mood Recognition

# %%
# %cd '/content/drive/MyDrive/Colab_Notebooks/Music Mood Recognition'
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Music Mood Recognition

# %%
# !ls
# Out:
# 1_Scraping.ipynb			    data		    output.wav
# 2_EDA					    EDA.py		    __pycache__
# 3_Modeling_with_preexisting_features.ipynb  funcs.ipynb		    scrapes
# 4_feature_engineering.ipynb		    funcs.py		    Scraping.py
# 5_modeling-with-extracted-features.ipynb    GenreTraniningModel.h5  test.mp3
# 6_Play.ipynb				    major-scale.mid
# auth.py					    midi_to_wav.ipynb

# %%
fs.midi_to_audio('major-scale.mid', 'output.mp3')
